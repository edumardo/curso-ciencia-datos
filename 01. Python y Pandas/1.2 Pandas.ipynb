# %% [markdown]
# # <center> Pandas

# %% [markdown]
# ## Download dataset ONLY IN COLAB

# %%
##### DOWNLOAD DATASET. ONLY IN COLAB !!!
# !wget -P ./../data/ https://raw.githubusercontent.com/CenticMurcia/curso-ciencia-datos/master/data/telecom_churn.csv
# Out:
# --2020-01-28 15:53:03--  https://raw.githubusercontent.com/CenticMurcia/curso-ciencia-datos/master/data/telecom_churn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 279997 (273K) [text/plain]
# Saving to: ‘./../data/telecom_churn.csv.1’
#
# telecom_churn.csv.1 100%[===================>] 273.43K  --.-KB/s    in 0.03s
#
# 2020-01-28 15:53:04 (8.47 MB/s) - ‘./../data/telecom_churn.csv.1’ saved [279997/279997]

# %%
# !cd sample_data/
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jan 13 16:38 .
# drwxr-xr-x 1 root root 4096 Jan 28 15:50 ..
# drwxr-xr-x 1 root root 4096 Jan 13 16:38 .config
# drwxr-xr-x 1 root root 4096 Jan 13 16:38 sample_data

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd

# Opciones de imppresión
pd.set_option("display.precision", 2)      # Display 2 decimals
pd.set_option('display.max_columns', 1000) # Display all variables

# %% [markdown]
# ## Create dataframe `df`

# %%
df = pd.read_csv('../data/telecom_churn.csv')
df.head()   # Muestra las 5 primeras lineas por defecto, tbn puede ser df.head(3)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# > # Remember
# > ### Column = Variable = Feature = Dimension
# > ### Row = Case = Point
#
# ## See shape

# %%
print("Shape:", df.shape)   # rows X columns
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Shape: (3333, 20)
# Number of rows: 3333
# Number of columns: 20

# %% [markdown]
# ## See variables

# %%
for d in df.columns:
    print(d)

print(df.columns)
# Out:
# State
# Account length
# Area code
# International plan
# Voice mail plan
# Number vmail messages
# Total day minutes
# Total day calls
# Total day charge
# Total eve minutes
# Total eve calls
# Total eve charge
# Total night minutes
# Total night calls
# Total night charge
# Total intl minutes
# Total intl calls
# Total intl charge
# Customer service calls
# Churn
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ## Show variable types with `info()`

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %% [markdown]
# ## Show statistics of numeric variables

# %%
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# ...

# %%
df['Area code'] = df['Area code'].astype(object)    # Marcamos 'Area code' como columna categórica
df.describe()   # ya no sale 'Area code'
# Out:
#        Account length  Number vmail messages  Total day minutes  \
# count         3333.00                3333.00            3333.00
# mean           101.06                   8.10             179.78
# std             39.82                  13.69              54.47
# min              1.00                   0.00               0.00
# 25%             74.00                   0.00             143.70
# 50%            101.00                   0.00             179.40
# 75%            127.00                  20.00             216.40
# max            243.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# std              20.07              9.26              50.71            19.92
# min               0.00              0.00               0.00             0.00
# ...

# %% [markdown]
# ## Show statistics of categoric variables

# %%
df.describe(include=['object', 'bool'])   # Estadísticas de variables categóricas y booleanas
# Out:
#        State  Area code International plan Voice mail plan  Churn
# count   3333       3333               3333            3333   3333
# unique    51          3                  2               2      2
# top       WV        415                 No              No  False
# freq     106       1655               3010            2411   2850

# %%
df['Area code'].describe()
# Out:
# 0       415
# 1       415
# 2       415
# 3       408
# 4       415
#        ...
# 3328    415
# 3329    415
# 3330    510
# 3331    510
# 3332    415
# Name: Area code, Length: 3333, dtype: object

# %% [markdown]
# ## Select 1 variable (serie)

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df["State"]
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %% [markdown]
# ## Select multiple variables

# %%
df[["State", "Account length", "Area code"]]
# Out:
#      State  Account length Area code
# 0       KS             128       415
# 1       OH             107       415
# 2       NJ             137       415
# 3       OH              84       408
# 4       OK              75       415
# ...    ...             ...       ...
# 3328    AZ             192       415
# 3329    WV              68       415
# 3330    RI              28       510
# 3331    CT             184       510
# 3332    TN              74       415
#
# [3333 rows x 3 columns]

# %% [markdown]
# ## Numerical variable -> Min, max, mean, median, std, ...

# %%
df['Account length'].min()
# Out:
# 1

# %%
df['Account length'].max()
# Out:
# 243

# %%
df['Account length'].mean()
# Out:
# 101.06480648064806

# %%
df['Account length'].median()
# Out:
# 101.0

# %%
df['Account length'].std()
# Out:
# 39.822105928595604

# %% [markdown]
# ## Categorical variable -> Count unique values

# %%
df['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# False    0.86
# True     0.14
# Name: Churn, dtype: float64

# %%
# Show top 10 in a dataframe
pd.DataFrame({  'Recuento':   df['State'].value_counts(),
                'Porcentaje': df['State'].value_counts(normalize=True) * 100
             }).head(5)
# Out:
#     Recuento  Porcentaje
# WV       106        3.18
# MN        84        2.52
# NY        83        2.49
# AL        80        2.40
# WI        78        2.34

# %% [markdown]
# ## Categorial varaibles -> Cross table
# #### Also known as Contingency table

# %%
pd.crosstab(df['Churn'], df['International plan'])
# Out:
# International plan    No  Yes
# Churn
# False               2664  186
# True                 346  137

# %%
pd.crosstab(df['Churn'], df['International plan'], margins=True)
# Out:
# International plan    No  Yes   All
# Churn
# False               2664  186  2850
# True                 346  137   483
# All                 3010  323  3333

# %%
pd.crosstab(df['Churn'], df['Voice mail plan'], normalize=True)
# Out:
# Voice mail plan    No   Yes
# Churn
# False            0.60  0.25
# True             0.12  0.02

# %% [markdown]
# ## Numeric & Categorial varaibles -> Pivot table

# %%
df.pivot_table(['Total day calls', 'Total eve calls', 'Total night calls'],
               ['State'], aggfunc='mean').head()
# Out:
#        Total day calls  Total eve calls  Total night calls
# State
# AK               95.27            96.58              97.35
# AL               99.10            98.46              98.61
# AR              102.15            97.84              99.05
# AZ              100.11           102.41              99.98
# CA              104.50           103.09              99.21

# %%
df.pivot_table(['Total day calls', 'Total eve calls', 'Total night calls'],
               ['State', "Churn"], aggfunc='mean').head()
# Out:
#              Total day calls  Total eve calls  Total night calls
# State Churn
# AK    False            95.59            96.39              97.55
#       True             90.00            99.67              94.00
# AL    False            99.39            99.25              98.40
#       True             96.50            91.38             100.50
# AR    False           101.91            94.84              96.34

# %% [markdown]
# # <center> Filters

# %% [markdown]
# ## 1 Filter

# %%
df[df['Churn'] == True]
df[df['State'] == 'MD']
df[df['Total day calls'] > 150].head(5)
# Out:
#      State  Account length Area code International plan Voice mail plan  \
# 164     OK             146       415                 No              No
# 315     MA              39       408                 No              No
# 468     AZ              86       415                 No             Yes
# 580     IN             113       415                 No              No
# 1057    WV              86       415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 164                       0              206.3              151
# 315                       0               60.4              158
# 468                      32               70.9              163
# 580                       0              209.4              151
# 1057                     38              123.0              158
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df[(df['Total day minutes'] > 150) & (df['Total day charge'] < 150)].tail(3)
# Out:
#      State  Account length Area code International plan Voice mail plan  \
# 3330    RI              28       510                 No              No
# 3331    CT             184       510                Yes              No
# 3332    TN              74       415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# ...

# %%
df[df['Voice mail plan'] == 'Yes'].head(3)
# Out:
#   State  Account length Area code International plan Voice mail plan  \
# 0    KS             128       415                 No             Yes
# 1    OH             107       415                 No             Yes
# 6    MA             121       510                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 6                     24              218.2               88
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 6             37.09              348.5              108             29.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# ...

# %% [markdown]
# ## Multiple filters

# %%
df[ (df['Churn']==False) & (df['International plan']=='No')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # <center> Dataframe Modification

# %% [markdown]
# # <center> Summary
# - The data table is a Pandas **dataframe**
# - The data column is a Pandas **series**
# - We can obtain information of the **dataset**:
#   - 10 top rows: `df.head(10)`
#   - Number of rows & variables: `df.shape`
#   - Names of variables: `df.columns`
#   - Types of variables: `df.info()`
#   - Stats of numerical variables: `df.describe()`
#   - Stats of numerical variables: `df.describe(include=['object', 'bool'])`
# - Information of **numerical variables**:
#   - Minimum `df.num_var.min()`
#   - Maximun `df.num_var.max()`
#   - Mean `df.num_var.mean()`
#   - Median `df.num_var.median()`
#   - Std `df.variable.std()`
# - Information of **categorical variables**:
#   - Unique values (count): `df.cat_var.value_counts()`
#   - Unique values (percent): `df.cat_var.value_counts(normalize=True)`
#   - 2 categorial vars (count): `pd.crosstab(df.cat_var1, df.cat_var2, margins=True)`
#   - 2 categorial vars (percen): `pd.crosstab(df.cat_var1, df.cat_var2, margins=True, normalize=True)`
# - Information of **numerical & categorial variables**:
#   - Pivot table: `df.pivot_table([num_var1, num_var2, ...], [cat_var1, cat_var2], aggfunc='mean')`
# - **Fitering rows**:
#   - One filter: `df[ condition ]`
#   - Multiple filters: `df[ (condition1) & (condition2)]`

# %% [markdown]
# # <center> Bonus: Pandas Profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %%
profile

# %% [markdown]
# # <center> Fin
